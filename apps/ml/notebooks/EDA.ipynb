# %% [markdown]
# # EDA · Inibsa Smart Demand Signals
#
# Hallazgos a producir en h1–h3:
# - volumen total (filas, clientes únicos, productos únicos)
# - distribución temporal (¿hay huecos? ¿estacionalidad evidente?)
# - % devoluciones (`valor < 0`) y ceros
# - distribución de potenciales (NA, absurdos, deciles)
# - agrupación de SKUs en commodity vs technical (proponer al equipo)
#
# Output: 1-pager en Markdown que el equipo lee en h3.

# %%
import pandas as pd
import duckdb
from pathlib import Path

DATA = Path('../../../data/raw')
list(DATA.iterdir())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 import duckdb
#       3 from pathlib import Path
#       5 DATA = Path('../../../data/raw')
#
# ModuleNotFoundError: No module named 'duckdb'
